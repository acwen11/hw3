# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import rc
from matplotlib.ticker import FuncFormatter
import os

rc('text',usetex=True)
rc('font',**{'family':'serif','serif':['Times New Roman'],'size':14})#,'weight':'bold'})
rc('xtick',**{'labelsize':16})
rc('ytick',**{'labelsize':16})
rc('axes',**{'labelsize':18,'titlesize':18})

# %%
# Indices 0:t 1-3:x 4-6:v 7:E 8-10:L 11:r 12:|L| 13:omega? 14:eccen 15-17:evect
# out2 0:rcyl 1:vcyl

fig3_4_1 = np.loadtxt("3_4a.dat").T
fig3_4_1[7][0]
# Out:
# -0.8

# %%
plt.plot(np.sqrt(fig3_4_1[1]**2 + fig3_4_1[2]**2), fig3_4_1[3])
plt.xlim(0, 0.5)
plt.ylim(-0.2, 0.2)
plt.xlabel("R")
plt.ylabel("z")
plt.grid()
plt.title("Fig. 3.4a")
plt.show()

# %%
plt.plot(np.sqrt(fig3_4_b[1]**2 + fig3_4_b[2]**2), fig3_4_b[3])
plt.xlim(0, 0.5)
plt.ylim(-0.2, 0.2)
plt.xlabel("R")
plt.ylabel("z")
plt.grid()
plt.title("Fig. 3.4b")
plt.show()

# %%
fig3_6 = np.loadtxt("3_4a.dat").T
fig3_6[0][-1]
# Out:
# 25.9643

# %%
plt.plot(fig3_6[0][fig3_6[0] < 20], fig3_6[12][fig3_6[0] < 20])
plt.ylim(0, 0.3)
plt.xlabel("t")
plt.ylabel("L")
plt.grid()
plt.title("Fig. 3.6a")
plt.show()

# %%
plt.plot(fig3_6[0][(1000 < fig3_6[0]) & (fig3_6[0] < 1020)], fig3_6[12][(1000 < fig3_6[0]) & (fig3_6[0] < 1020)])
plt.ylim(0, 0.3)
plt.xlabel("t")
plt.ylabel("L")
plt.grid()
plt.title("Fig. 3.6b")
plt.show()

# %%
fig3_8a = np.loadtxt("3_8a.dat").T
plt.plot(fig3_8a[1], fig3_8a[2])
plt.ylim(-0.18, 0.18)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fig. 3.8a")
plt.show()

# %%
fig3_8b = np.loadtxt("3_8b.dat").T
fig, ax = plt.subplots()
ax.set_box_aspect(1)
plt.plot(fig3_8b[1], fig3_8b[2])
plt.ylim(-0.6, 0.6)
plt.xlim(-0.6, 0.6)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fig. 3.8b")
plt.show()

# %%
fig3_10a = np.loadtxt("3_10a.dat").T
fig, ax = plt.subplots()
ax.set_box_aspect(1)
plt.plot(fig3_10a[1], fig3_10a[2])
plt.ylim(-0.6, 0.6)
plt.xlim(-0.6, 0.6)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fig. 3.10a")
plt.show()

# %%
fig3_10b = np.loadtxt("3_10b.dat").T
fig, ax = plt.subplots()
ax.set_box_aspect(1)
plt.plot(fig3_10b[1], fig3_10b[2])
plt.ylim(-0.6, 0.6)
plt.xlim(-0.6, 0.6)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fig. 3.10b")
plt.show()

# %%
fig3_10c = np.loadtxt("3_10c.dat").T
fig, ax = plt.subplots()
ax.set_box_aspect(1)
plt.plot(fig3_10c[1], fig3_10c[2])
plt.ylim(-0.8, 0.8)
plt.xlim(-0.8, 0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fig. 3.10c")
plt.show()

# %%
fig3_10d = np.loadtxt("3_10d.dat").T
fig, ax = plt.subplots()
ax.set_box_aspect(1)
plt.plot(fig3_10d[1], fig3_10d[2])
plt.ylim(-0.8, 0.8)
plt.xlim(-0.8, 0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fig. 3.10d")
plt.show()

# %%
fig3_10e = np.loadtxt("3_10e.dat").T
fig, ax = plt.subplots()
ax.set_box_aspect(1)
plt.plot(fig3_10e[1], fig3_10e[2])
plt.ylim(-0.8, 0.8)
plt.xlim(-0.8, 0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fig. 3.10e")
plt.show()

# %%
fig3_10f = np.loadtxt("orbit.dat").T
fig, ax = plt.subplots()
ax.set_box_aspect(1)
plt.plot(fig3_10f[1], fig3_10f[2])
plt.ylim(-0.8, 0.8)
plt.xlim(-0.8, 0.8)
plt.xlabel("x")
plt.ylabel("y")
plt.title("Fig. 3.10f")
plt.show()
